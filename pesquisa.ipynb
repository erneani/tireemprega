# %%
# Loading Pandas lib to perform Data Analysis on Courses CSV
import pandas as pd

df = pd.read_csv('./datasets/tech-courses.csv')

# %%
# Checking table head
df.head()
# Out:
#       course_id                                       course_title  \
# 1200  1227578.0           Learning Path: The Road to Elasticsearch
# 1201  1277924.0                            Angular 4 Front To Back
# 1202  1248172.0            Essentials of Spring 5.0 for Developers
# 1203  1250934.0  Display and analyze GIS data on the web with L...
# 1204  1270222.0  Learning Path: Web Applications with Spring an...
#
#                                                     url  price  \
# 1200  https://www.udemy.com/learning-path-the-road-t...  200.0
# 1201     https://www.udemy.com/angular-4-front-to-back/   40.0
# 1202  https://www.udemy.com/essentials-of-spring-50-...  125.0
# 1203  https://www.udemy.com/display-and-analyze-gis-...  100.0
# 1204  https://www.udemy.com/learning-path-web-applic...  200.0
#
#       num_subscribers  num_reviews  num_lectures           level  Rating  \
# 1200             50.0          5.0          60.0  Beginner Level    0.96
# ...

# %%
# Checking table Columns info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1205 entries, 0 to 1204
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   course_id            1203 non-null   float64
#  1   course_title         1203 non-null   object
#  2   url                  1203 non-null   object
#  3   price                1203 non-null   float64
#  4   num_subscribers      1203 non-null   float64
#  5   num_reviews          1203 non-null   float64
#  6   num_lectures         1203 non-null   float64
#  7   level                1203 non-null   object
#  8   Rating               1203 non-null   float64
#  9   content_duration     1203 non-null   float64
#  10  published_timestamp  1203 non-null   object
#  11  subject              1204 non-null   object
# dtypes: float64(7), object(5)
# memory usage: 113.1+ KB

# %%
# Checking statistics for all non-object values
df.describe()
# Out:
#           course_id        price  num_subscribers   num_reviews  num_lectures  \
# count  1.203000e+03  1203.000000      1203.000000   1203.000000   1203.000000
# mean   7.068747e+05    77.036575      6635.024938    357.355777     52.767249
# std    3.287600e+05    66.145420     14559.419007   1572.917685     62.762267
# min    8.324000e+03     0.000000        19.000000      0.000000      5.000000
# 25%    4.750150e+05    20.000000      1128.500000     25.000000     19.000000
# 50%    7.383600e+05    50.000000      2430.000000     65.000000     32.000000
# 75%    9.754830e+05   115.000000      6947.500000    179.000000     63.500000
# max    1.277924e+06   200.000000    268923.000000  27445.000000    779.000000
#
#             Rating  content_duration
# count  1203.000000       1203.000000
# mean      0.643051          5.586658
# std       0.306004          7.242855
# min       0.000000          0.500000
# 25%       0.340000          1.500000
# 50%       0.760000          3.000000
# ...

# %%
# Getting Subject column to verify it's values
df.groupby('subject').value_counts()
# Out:
# subject                   course_id  course_title                                                  url                                                                              price  num_subscribers  num_reviews  num_lectures  level           Rating  content_duration  published_timestamp
# Subject: Web Development  8324.0     Javascript for Beginners                                      https://www.udemy.com/beginning-javascript/                                      20.0   3697.0           195.0        48.0          All Levels      0.11    3.0               2011-07-09T05:43:31Z    1
#                           912996.0   The Bubble Course - Create Complete Web Apps without Coding   https://www.udemy.com/bubble-course/                                             30.0   3960.0           220.0        47.0          Beginner Level  0.92    4.5               2016-07-24T18:04:32Z    1
# ...

# %%
# Okay, all this data is under Web Development subject, so this column is not useful at all
# Let's remove it
df.drop('subject', axis=1, inplace=True)

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1205 entries, 0 to 1204
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   course_id            1203 non-null   float64
#  1   course_title         1203 non-null   object
#  2   url                  1203 non-null   object
#  3   price                1203 non-null   float64
#  4   num_subscribers      1203 non-null   float64
#  5   num_reviews          1203 non-null   float64
#  6   num_lectures         1203 non-null   float64
#  7   level                1203 non-null   object
#  8   Rating               1203 non-null   float64
#  9   content_duration     1203 non-null   float64
#  10  published_timestamp  1203 non-null   object
# dtypes: float64(7), object(4)
# memory usage: 103.7+ KB

# %%
# Let's keep dropping tables to make our DataSet simple
# We will only need:
# - Course Title
# - Course URL
# - Course Price
# - Num Subscribers
# - Rating
# - Level
# - Content Duration
# - Published Timestamp
df.drop(['course_id', 'num_reviews', 'num_lectures'], axis=1, inplace=True)

# %%
# Checking our DF now
df.head()
# Out:
#                                         course_title  \
# 0               Learn HTML5 Programming From Scratch
# 1                     Coding for Entrepreneurs Basic
# 2                         The Web Developer Bootcamp
# 3  Build Your First Website in 1 Week with HTML5 ...
# 4              The Complete Web Developer Course 2.0
#
#                                                  url  price  num_subscribers  \
# 0  https://www.udemy.com/learn-html5-programming-...    0.0         268923.0
# 1  https://www.udemy.com/coding-for-entrepreneurs...    0.0         161029.0
# 2  https://www.udemy.com/the-web-developer-bootcamp/  200.0         121584.0
# 3  https://www.udemy.com/build-your-first-website...    0.0         120291.0
# 4  https://www.udemy.com/the-complete-web-develop...  200.0         114512.0
#
#             level  Rating  content_duration   published_timestamp
# 0  Beginner Level    0.82              10.5  2013-02-14T07:03:41Z
# ...

# %%
# Great, now let's our algorithm using this clean DataSet!
df.to_csv('./datasets/tech-courses-modified.csv')
